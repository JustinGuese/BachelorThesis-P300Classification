# %%
subj1 = [('PO10_2', 0.79243124),
 ('C4_2', 0.8006881),
 ('FC1_2', 0.8006881),
 ('T8_2', 0.80091745),
 ('C4_1', 0.80481654),
 ('T8_1', 0.805734),
 ('Cz_2', 0.80917436),
 ('CP5_2', 0.8105505),
 ('CP1_2', 0.81261474),
 ('Pz_1', 0.81376153),
 ('Cz_1', 0.8155964),
 ('O1_2', 0.81582576),
 ('CP2_2', 0.8162845),
 ('C3_2', 0.8188074),
 ('C3_1', 0.81926614),
 ('FC5_2', 0.82018346),
 ('FC2_2', 0.8206423),
 ('PO9_2', 0.82087165),
 ('P3_2', 0.8220183),
 ('T7_2', 0.8238533),
 ('P7_2', 0.825),
 ('FC6_2', 0.82568806),
 ('FP2_2', 0.8259174),
 ('CP6_2', 0.82637614),
 ('FP1_2', 0.8277523),
 ('P4_1', 0.82844037),
 ('Pz_2', 0.8288991),
 ('P8_1', 0.8293578),
 ('CP1_1', 0.83027524),
 ('FC6_1', 0.8309633),
 ('Oz_2', 0.8309633),
 ('PO8_2', 0.8311927),
 ('F7_1', 0.8316514),
 ('P4_2', 0.8321101),
 ('FC1_1', 0.83233947),
 ('O2_2', 0.8332569),
 ('CP2_1', 0.83348626),
 ('F7_2', 0.83509177),
 ('T7_1', 0.83509177),
 ('FC5_1', 0.8355505),
 ('F3_2', 0.83577985),
 ('P3_1', 0.83577985),
 ('P8_2', 0.83692664),
 ('F3_1', 0.83738536),
 ('AFz_1', 0.83807343),
 ('F4_2', 0.83807343),
 ('PO7_1', 0.8392202),
 ('FC2_1', 0.83967894),
 ('PO7_2', 0.83967894),
 ('PO10_1', 0.840367),
 ('P7_1', 0.84128445),
 ('F8_1', 0.8419725),
 ('CP5_1', 0.8422018),
 ('CP6_1', 0.8422018),
 ('FP2_1', 0.84311926),
 ('O1_1', 0.84380734),
 ('AFz_2', 0.8440367),
 ('PO8_1', 0.8440367),
 ('F4_1', 0.8456422),
 ('F8_2', 0.8463303),
 ('Oz_1', 0.846789),
 ('FP1_1', 0.84885323),
 ('PO9_1', 0.8490826),
 ('O2_1', 0.8522936)]


subj2 = [('C3_1', 0.7598624),
 ('F7_2', 0.76353216),
 ('Cz_1', 0.76376146),
 ('PO10_2', 0.7637615),
 ('T7_1', 0.7646789),
 ('CP5_1', 0.765367),
 ('CP1_1', 0.76536703),
 ('FC6_1', 0.7665137),
 ('T8_1', 0.76651376),
 ('F3_2', 0.7665138),
 ('Pz_2', 0.7667432),
 ('F4_2', 0.7681192),
 ('CP2_1', 0.76857793),
 ('PO7_2', 0.76926607),
 ('C4_1', 0.76995414),
 ('F8_1', 0.77133024),
 ('FC1_2', 0.77133024),
 ('FC5_2', 0.7722477),
 ('P3_2', 0.7727064),
 ('FC5_1', 0.77293575),
 ('AFz_2', 0.7736238),
 ('F8_2', 0.7743119),
 ('FC2_2', 0.77454126),
 ('P4_2', 0.77454126),
 ('F3_1', 0.77522933),
 ('F7_1', 0.7759174),
 ('F4_1', 0.7766055),
 ('FC2_1', 0.7770642),
 ('P7_2', 0.7788991),
 ('FP2_2', 0.7798165),
 ('O1_2', 0.7798165),
 ('FC1_1', 0.7805046),
 ('FC6_2', 0.78073394),
 ('PO9_2', 0.7809633),
 ('CP6_2', 0.78119266),
 ('P8_2', 0.7816514),
 ('T7_2', 0.7825688),
 ('C3_2', 0.7827982),
 ('PO8_2', 0.78348625),
 ('PO9_1', 0.78348625),
 ('CP5_2', 0.7848624),
 ('FP1_2', 0.7848624),
 ('PO8_1', 0.7848624),
 ('PO7_1', 0.7860092),
 ('O2_1', 0.7864679),
 ('AFz_1', 0.78669727),
 ('CP1_2', 0.7883028),
 ('O2_2', 0.7887615),
 ('CP6_1', 0.7892202),
 ('P8_1', 0.7894496),
 ('PO10_1', 0.7894496),
 ('O1_1', 0.79013765),
 ('C4_2', 0.79128444),
 ('Cz_2', 0.7915138),
 ('T8_2', 0.79174316),
 ('CP2_2', 0.7926606),
 ('Oz_1', 0.7942661),
 ('FP2_1', 0.7970184),
 ('FP1_1', 0.8006881),
 ('Oz_2', 0.80137616),
 ('P4_1', 0.80252296),
 ('Pz_1', 0.80596334),
 ('P7_1', 0.80642205),
 ('P3_1', 0.8077982)]

subj3 = [('C3_1', 0.7598624),
 ('F7_2', 0.76353216),
 ('Cz_1', 0.76376146),
 ('PO10_2', 0.7637615),
 ('T7_1', 0.7646789),
 ('CP5_1', 0.765367),
 ('CP1_1', 0.76536703),
 ('FC6_1', 0.7665137),
 ('T8_1', 0.76651376),
 ('F3_2', 0.7665138),
 ('Pz_2', 0.7667432),
 ('F4_2', 0.7681192),
 ('CP2_1', 0.76857793),
 ('PO7_2', 0.76926607),
 ('C4_1', 0.76995414),
 ('F8_1', 0.77133024),
 ('FC1_2', 0.77133024),
 ('FC5_2', 0.7722477),
 ('P3_2', 0.7727064),
 ('FC5_1', 0.77293575),
 ('AFz_2', 0.7736238),
 ('F8_2', 0.7743119),
 ('FC2_2', 0.77454126),
 ('P4_2', 0.77454126),
 ('F3_1', 0.77522933),
 ('F7_1', 0.7759174),
 ('F4_1', 0.7766055),
 ('FC2_1', 0.7770642),
 ('P7_2', 0.7788991),
 ('FP2_2', 0.7798165),
 ('O1_2', 0.7798165),
 ('FC1_1', 0.7805046),
 ('FC6_2', 0.78073394),
 ('PO9_2', 0.7809633),
 ('CP6_2', 0.78119266),
 ('P8_2', 0.7816514),
 ('T7_2', 0.7825688),
 ('C3_2', 0.7827982),
 ('PO8_2', 0.78348625),
 ('PO9_1', 0.78348625),
 ('CP5_2', 0.7848624),
 ('FP1_2', 0.7848624),
 ('PO8_1', 0.7848624),
 ('PO7_1', 0.7860092),
 ('O2_1', 0.7864679),
 ('AFz_1', 0.78669727),
 ('CP1_2', 0.7883028),
 ('O2_2', 0.7887615),
 ('CP6_1', 0.7892202),
 ('P8_1', 0.7894496),
 ('PO10_1', 0.7894496),
 ('O1_1', 0.79013765),
 ('C4_2', 0.79128444),
 ('Cz_2', 0.7915138),
 ('T8_2', 0.79174316),
 ('CP2_2', 0.7926606),
 ('Oz_1', 0.7942661),
 ('FP2_1', 0.7970184),
 ('FP1_1', 0.8006881),
 ('Oz_2', 0.80137616),
 ('P4_1', 0.80252296),
 ('Pz_1', 0.80596334),
 ('P7_1', 0.80642205),
 ('P3_1', 0.8077982)]

subj4 = [('PO10_2', 0.8144496),
 ('F4_2', 0.81467897),
 ('O2_1', 0.81582576),
 ('T7_1', 0.8188074),
 ('PO8_1', 0.81972486),
 ('F8_1', 0.8206423),
 ('FC1_1', 0.8215597),
 ('AFz_2', 0.8217891),
 ('FC6_1', 0.8222477),
 ('Oz_1', 0.8222477),
 ('PO9_1', 0.8231651),
 ('FP1_2', 0.8233945),
 ('FP2_2', 0.8233945),
 ('C3_1', 0.8233946),
 ('FC2_1', 0.8240827),
 ('P3_1', 0.8245413),
 ('C4_1', 0.82522947),
 ('F4_1', 0.8259174),
 ('P7_1', 0.8259174),
 ('T7_2', 0.82637614),
 ('CP6_1', 0.8266055),
 ('O1_1', 0.8266055),
 ('F3_1', 0.826835),
 ('F7_2', 0.8272936),
 ('F8_2', 0.8277523),
 ('P8_1', 0.82798165),
 ('PO7_1', 0.828211),
 ('P4_1', 0.82844037),
 ('F7_1', 0.8293578),
 ('AFz_1', 0.8305046),
 ('Pz_1', 0.8309633),
 ('CP2_1', 0.8311927),
 ('C3_2', 0.8321101),
 ('CP5_1', 0.83233947),
 ('PO10_1', 0.8325688),
 ('PO8_2', 0.8325688),
 ('FC5_1', 0.83348626),
 ('FP2_1', 0.8337156),
 ('Oz_2', 0.8337156),
 ('F3_2', 0.833945),
 ('O2_2', 0.833945),
 ('FC2_2', 0.8360092),
 ('FC6_2', 0.8360092),
 ('CP1_1', 0.8366973),
 ('Cz_1', 0.837156),
 ('T8_2', 0.83738536),
 ('C4_2', 0.83853215),
 ('FP1_1', 0.8387615),
 ('T8_1', 0.83899087),
 ('Cz_2', 0.8392202),
 ('FC1_2', 0.8394496),
 ('P4_2', 0.84082574),
 ('Pz_2', 0.84197253),
 ('P3_2', 0.84311926),
 ('CP1_2', 0.8433486),
 ('P8_2', 0.84380734),
 ('CP6_2', 0.8447248),
 ('PO9_2', 0.8447248),
 ('FC5_2', 0.8451835),
 ('P7_2', 0.8461009),
 ('CP2_2', 0.84701836),
 ('O1_2', 0.8486239),
 ('PO7_2', 0.85091746),
 ('CP5_2', 0.85321105)]

# %%
# assign position to channel
score_dict = {}

all_subjects = [subj1,subj2,subj3,subj4]

for subj in all_subjects:
    for i,(x,y) in enumerate(subj):
        if x in score_dict:
            crnt = score_dict[x]
            score_dict[x] = i + crnt
        else:
            score_dict[x] = i
            
# the lower the number the higher the avg position / feature importance
sorted_importances = {k: v/len(all_subjects) for k, v in sorted(score_dict.items(), key=lambda item: item[1])}
just_channel_names = [k for k, v in sorted(score_dict.items(), key=lambda item: item[1])]
sorted_importances,just_channel_names
# Out:
# ({'PO10_2': 1.5,
#   'C3_1': 6.75,
#   'C4_1': 12.0,
#   'T7_1': 12.25,
#   'FC6_1': 12.75,
#   'Cz_1': 14.5,
#   'F7_2': 15.5,
#   'F4_2': 17.0,
#   'T8_1': 17.25,
#   'CP1_1': 20.75,
#   'FC1_2': 21.0,
#   'F8_1': 21.5,
#   'CP2_1': 22.75,
#   'FP2_2': 23.0,
#   'CP5_1': 23.75,
#   'F3_2': 24.25,
#   'Pz_2': 24.5,
#   'FC2_2': 25.25,
#   'FC1_1': 25.5,
#   'AFz_2': 25.75,
#   'FC5_2': 26.75,
#   'P3_2': 26.75,
#   'T7_2': 27.5,
#   'F7_1': 27.5,
#   'FC5_1': 28.25,
#   'F3_1': 28.25,
#   'FC2_1': 28.75,
#   'FP1_2': 29.25,
#   'C3_2': 29.75,
#   'F8_2': 31.25,
#   'FC6_2': 31.75,
#   'F4_1': 31.75,
#   'P4_2': 32.5,
#   'O1_2': 33.0,
#   'P7_2': 33.75,
#   'PO7_2': 34.0,
#   'PO9_2': 35.0,
#   'PO8_2': 35.5,
#   'PO8_1': 36.25,
#   'CP6_2': 36.75,
#   'CP5_2': 37.5,
#   'P8_1': 37.5,
#   'PO9_1': 37.5,
#   'C4_2': 37.75,
#   'O2_1': 38.25,
#   'CP1_2': 38.5,
#   'T8_2': 39.0,
#   'PO7_1': 39.5,
#   'Cz_2': 40.25,
#   'Pz_1': 40.25,
#   'AFz_1': 40.75,
#   'P8_2': 41.75,
# ...

# %%
# is channel number:
[63,
 37,
 28,
 11,
 29,
 6,
 8,
 34,
 63,
 28,
 29,
 8,
 10,
 30,
 33,
 9,
 63,
 11,
 8,
 27,
 33,
 21,
 20,
 26,
 63,
 29,
 10,
 33,
 14,
 19,
 38,
 3,
 63,
 6,
 30,
 21,
 19,
 24,
 22,
 61,
 63,
 8,
 33,
 20,
 38,
 22,
 7,
 42,
 63,
 34,
 9,
 26,
 3,
 61,
 42,
 45,
 63,
 10,
 14,
 38,
 44,
 60,
 15,
 51,
 63,
 27,
 20,
 23,
 7,
 47,
 49,
 48]
